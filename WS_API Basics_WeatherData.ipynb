# %% [markdown]
# # Introduction

# %% [markdown]
# # APIs
#
# - Short for **'Application Programming Interface'**.
# - Basically, API is a tool that helps to get data from a 'database' by defined calls and requests. This 'database' could be a web-based system, operating system, database, or computer hardware. For instance, you can access and get data from YouTube or Twitter APIs.
#
# Here, I provide an example of extracting data from weather API.(https://www.weather.gov/documentation/services-web-api#).
# - Data from APIs are normally in a JSON format, which is used as a standard for communicate API information.

# %% [markdown]
# # Case Example - Get Weather Data from API

# %%
# import libraries
import requests
raw_data = requests.get('https://api.weather.gov/points/39.7456,-97.0892')

# %%
raw_data
# Out:
# <Response [200]>

# %%
# check how the request went
raw_data.status_code
# Out:
# 200

# %% [markdown]
# - So now, I have successfully accessed the data. (200 success code; 404 or 4-- means error)

# %%
# check the headers of the page
raw_data.headers
# Out:
# {'Server': 'nginx/1.16.1', 'Content-Type': 'application/geo+json', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'Feature-Flags', 'X-Request-ID': '117740c1-a827-4aa4-813d-5b185bac42de', 'X-Correlation-ID': '15865c6b', 'X-Server-ID': 'vm-lnx-nids-apiapp8.ncep.noaa.gov', 'Content-Encoding': 'gzip', 'Content-Length': '806', 'Cache-Control': 'public, max-age=5394, s-maxage=120', 'Expires': 'Fri, 06 Nov 2020 23:22:46 GMT', 'Date': 'Fri, 06 Nov 2020 21:52:52 GMT', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding, Accept,Feature-Flags,Accept-Language', 'X-Edge-Request-ID': '26a1e19c', 'Strict-Transport-Security': 'max-age=31536000 ; includeSubDomains ; preload'}

# %%
# check the content of the page
raw_data.content # can also use raw_data.text
# Out:
# b'{\n    "@context": [\n        "https://geojson.org/geojson-ld/geojson-context.jsonld",\n        {\n            "@version": "1.1",\n            "wx": "https://api.weather.gov/ontology#",\n            "s": "https://schema.org/",\n            "geo": "http://www.opengis.net/ont/geosparql#",\n            "unit": "http://codes.wmo.int/common/unit/",\n            "@vocab": "https://api.weather.gov/ontology#",\n            "geometry": {\n                "@id": "s:GeoCoordinates",\n                "@type": "geo:wktLiteral"\n            },\n            "city": "s:addressLocality",\n            "state": "s:addressRegion",\n            "distance": {\n                "@id": "s:Distance",\n                "@type": "s:QuantitativeValue"\n            },\n            "bearing": {\n                "@type": "s:QuantitativeValue"\n            },\n            "value": {\n                "@id": "s:value"\n            },\n            "unitCode": {\n                "@id": "s:unitCode",\n                "@type": "@id"\n            },\n            "forecastOffice": {\n                "@type": "@id"\n            },\n            "forecastGridData": {\n                "@type": "@id"\n            },\n            "publicZone": {\n                "@type": "@id"\n            },\n            "county": {\n                "@type": "@id"\n            }\n        }\n    ],\n    "id": "https://api.weather.gov/points/39.7456,-97.0892",\n    "type": "Feature",\n    "geometry": {\n        "type": "Point",\n        "coordinates": [\n            -97.089200000000005,\n            39.745600000000003\n        ]\n    },\n    "properties": {\n        "@id": "https://api.weather.gov/points/39.7456,-97.0892",\n        "@type": "wx:Point",\n        "cwa": "TOP",\n        "forecastOffice": "https://api.weather.gov/offices/TOP",\n        "gridId": "TOP",\n        "gridX": 31,\n        "gridY": 80,\n        "forecast": "https://api.weather.gov/gridpoints/TOP/31,80/forecast",\n        "forecastHourly": "https://api.weather.gov/gridpoints/TOP/31,80/forecast/hourly",\n        "forecastGridData": "https://api.weather.gov/gridpoints/TOP/31,80",\n        "observationStations": "https://api.weather.gov/gridpoints/TOP/31,80/stations",\n        "relativeLocation": {\n            "type": "Feature",\n            "geometry": {\n                "type": "Point",\n                "coordinates": [\n                    -97.086661000000007,\n                    39.679375999999998\n                ]\n            },\n            "properties": {\n                "city": "Linn",\n                "state": "KS",\n                "distance": {\n                    "value": 7366.9851976443997,\n                    "unitCode": "unit:m"\n                },\n                "bearing": {\n                    "value": 358,\n                    "unitCode": "unit:degrees_true"\n                }\n            }\n        },\n        "forecastZone": "https://api.weather.gov/zones/forecast/KSZ009",\n        "county": "https://api.weather.gov/zones/county/KSC201",\n        "fireWeatherZone": "https://api.weather.gov/zones/fire/KSZ009",\n        "timeZone": "America/Chicago",\n        "radarStation": "KTWX"\n    }\n}'

# %% [markdown]
# - This document is in JSON format. So I will use '.json()' method to access data.

# %% [markdown]
# ### Extract data

# %%
# Show all the data in JSON formst
data_json = raw_data.json()
data_json
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    's': 'https://schema.org/',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#',
#    'geometry': {'@id': 's:GeoCoordinates', '@type': 'geo:wktLiteral'},
#    'city': 's:addressLocality',
#    'state': 's:addressRegion',
#    'distance': {'@id': 's:Distance', '@type': 's:QuantitativeValue'},
#    'bearing': {'@type': 's:QuantitativeValue'},
#    'value': {'@id': 's:value'},
#    'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#    'forecastOffice': {'@type': '@id'},
#    'forecastGridData': {'@type': '@id'},
#    'publicZone': {'@type': '@id'},
#    'county': {'@type': '@id'}}],
#  'id': 'https://api.weather.gov/points/39.7456,-97.0892',
#  'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-97.0892, 39.7456]},
#  'properties': {'@id': 'https://api.weather.gov/points/39.7456,-97.0892',
#   '@type': 'wx:Point',
#   'cwa': 'TOP',
#   'forecastOffice': 'https://api.weather.gov/offices/TOP',
#   'gridId': 'TOP',
#   'gridX': 31,
#   'gridY': 80,
#   'forecast': 'https://api.weather.gov/gridpoints/TOP/31,80/forecast',
#   'forecastHourly': 'https://api.weather.gov/gridpoints/TOP/31,80/forecast/hourly',
#   'forecastGridData': 'https://api.weather.gov/gridpoints/TOP/31,80',
#   'observationStations': 'https://api.weather.gov/gridpoints/TOP/31,80/stations',
#   'relativeLocation': {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-97.086661, 39.679376]},
#    'properties': {'city': 'Linn',
#     'state': 'KS',
#     'distance': {'value': 7366.9851976444, 'unitCode': 'unit:m'},
#     'bearing': {'value': 358, 'unitCode': 'unit:degrees_true'}}},
#   'forecastZone': 'https://api.weather.gov/zones/forecast/KSZ009',
#   'county': 'https://api.weather.gov/zones/county/KSC201',
#   'fireWeatherZone': 'https://api.weather.gov/zones/fire/KSZ009',
#   'timeZone': 'America/Chicago',
#   'radarStation': 'KTWX'}}

# %% [markdown]
# - The data is in a dictionary format. Now, I need to extarct the data needed from the dictionary.

# %%
# get the 'geo' within the dictionary with key of '@context'
# the values for the key '@context' is a list consists of ['string', dictionary]
data_json['@context'][1]['geo']
# Out:
# 'http://www.opengis.net/ont/geosparql#'

# %%
# Get Time Zone, which is in the dict of 'properties
data_json['properties']['timeZone']
# Out:
# 'America/Chicago'

# %% [markdown]
# - The TimeZone here is US/Chicago.

# %%
# check the hourly forecast, which is in the dict of 'properties
data_json['properties']['forecastHourly']
# Out:
# 'https://api.weather.gov/gridpoints/TOP/31,80/forecast/hourly'

# %% [markdown]
# - This leads to another JSON file of hourly weather forecast.

# %%
data_json['properties']['forecast']
# Out:
# 'https://api.weather.gov/gridpoints/TOP/31,80/forecast'

# %% [markdown]
# - This leads to another JSON file of overall daily weather forecast.

# %% [markdown]
# ### Get Hourly Weather Forecast

# %%
# Forecast
hourly_forecast_raw = requests.get(data_json['properties']['forecast'])
hourly_forecast_raw.text
# Out:
# '{\n    "@context": [\n        "https://geojson.org/geojson-ld/geojson-context.jsonld",\n        {\n            "@version": "1.1",\n            "wx": "https://api.weather.gov/ontology#",\n            "geo": "http://www.opengis.net/ont/geosparql#",\n            "unit": "http://codes.wmo.int/common/unit/",\n            "@vocab": "https://api.weather.gov/ontology#"\n        }\n    ],\n    "type": "Feature",\n    "geometry": {\n        "type": "Polygon",\n        "coordinates": [\n            [\n                [\n                    -97.1089731,\n                    39.766826299999998\n                ],\n                [\n                    -97.108526900000001,\n                    39.744778799999999\n                ],\n                [\n                    -97.079846700000004,\n                    39.745119500000001\n                ],\n                [\n                    -97.08028680000001,\n                    39.767167000000001\n                ],\n                [\n                    -97.1089731,\n                    39.766826299999998\n                ]\n            ]\n        ]\n    },\n    "properties": {\n        "updated": "2020-11-06T21:25:41+00:00",\n        "units": "us",\n        "forecastGenerator": "BaselineForecastGenerator",\n        "generatedAt": "2020-11-06T21:52:58+00:00",\n        "updateTime": "2020-11-06T21:25:41+00:00",\n        "validTimes": "2020-11-06T15:00:00+00:00/P7DT10H",\n        "elevation": {\n            "value": 441.95999999999998,\n            "unitCode": "unit:m"\n        },\n        "periods": [\n            {\n                "number": 1,\n                "name": "This Afternoon",\n                "startTime": "2020-11-06T15:00:00-06:00",\n                "endTime": "2020-11-06T18:00:00-06:00",\n                "isDaytime": true,\n                "temperature": 78,\n                "temperatureUnit": "F",\n                "temperatureTrend": null,\n                "windSpeed": "15 mph",\n                "windDirection": "S",\n                "icon": "https://api.weather.gov/icons/land/day/skc?size=medium",\n                "shortForecast": "Sunny",\n                "detailedForecast": "Sunny, with a high near 78. South wind around 15 mph, with gusts as high as 25 mph."\n            },\n            {\n                "number": 2,\n                "name": "Tonight",\n                "startTime": "2020-11-06T18:00:00-06:00",\n                "endTime": "2020-11-07T06:00:00-06:00",\n                "isDaytime": false,\n                "temperature": 56,\n                "temperatureUnit": "F",\n                "temperatureTrend": null,\n                "windSpeed": "15 mph",\n                "windDirection": "S",\n                "icon": "https://api.weather.gov/icons/land/night/sct?size=medium",\n                "shortForecast": "Partly Cloudy",\n                "detailedForecast": "Partly cloudy, with a low around 56. South wind around 15 mph, with gusts as high as 25 mph."\n            },\n            {\n                "number": 3,\n                "name": "Saturday",\n                "startTime": "2020-11-07T06:00:00-06:00",\n                "endTime": "2020-11-07T18:00:00-06:00",\n                "isDaytime": true,\n                "temperature": 73,\n                "temperatureUnit": "F",\n                "temperatureTrend": null,\n                "windSpeed": "15 to 20 mph",\n                "windDirection": "S",\n                "icon": "https://api.weather.gov/icons/land/day/sct?size=medium",\n                "shortForecast": "Mostly Sunny",\n                "detailedForecast": "Mostly sunny, with a high near 73. South wind 15 to 20 mph, with gusts as high as 30 mph."\n            },\n            {\n                "number": 4,\n                "name": "Saturday Night",\n                "startTime": "2020-11-07T18:00:00-06:00",\n                "endTime": "2020-11-08T06:00:00-06:00",\n                "isDaytime": false,\n                "temperature": 56,\n                ...

# %% [markdown]
# - This information is in a dictionary format. But I need it to be in a data frame format for further processing.

# %%
# extract infomation from the hourly_forest_raw data

# save raw data in json format
hourly_forecast = hourly_forecast_raw.json() 
hourly_forecast
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#'}],
#  'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-97.1089731, 39.7668263],
#     [-97.1085269, 39.7447788],
#     [-97.0798467, 39.7451195],
#     [-97.08028680000001, 39.767167],
#     [-97.1089731, 39.7668263]]]},
#  'properties': {'updated': '2020-11-06T21:25:41+00:00',
#   'units': 'us',
#   'forecastGenerator': 'BaselineForecastGenerator',
#   'generatedAt': '2020-11-06T21:52:58+00:00',
#   'updateTime': '2020-11-06T21:25:41+00:00',
#   'validTimes': '2020-11-06T15:00:00+00:00/P7DT10H',
#   'elevation': {'value': 441.96, 'unitCode': 'unit:m'},
#   'periods': [{'number': 1,
#     'name': 'This Afternoon',
#     'startTime': '2020-11-06T15:00:00-06:00',
#     'endTime': '2020-11-06T18:00:00-06:00',
#     'isDaytime': True,
#     'temperature': 78,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '15 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'shortForecast': 'Sunny',
#     'detailedForecast': 'Sunny, with a high near 78. South wind around 15 mph, with gusts as high as 25 mph.'},
#    {'number': 2,
#     'name': 'Tonight',
#     'startTime': '2020-11-06T18:00:00-06:00',
#     'endTime': '2020-11-07T06:00:00-06:00',
#     'isDaytime': False,
#     'temperature': 56,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '15 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#     'shortForecast': 'Partly Cloudy',
#     'detailedForecast': 'Partly cloudy, with a low around 56. South wind around 15 mph, with gusts as high as 25 mph.'},
#    {'number': 3,
#     'name': 'Saturday',
#     'startTime': '2020-11-07T06:00:00-06:00',
#     'endTime': '2020-11-07T18:00:00-06:00',
#     'isDaytime': True,
#     'temperature': 73,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '15 to 20 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'shortForecast': 'Mostly Sunny',
#     'detailedForecast': 'Mostly sunny, with a high near 73. South wind 15 to 20 mph, with gusts as high as 30 mph.'},
#    {'number': 4,
#     'name': 'Saturday Night',
#     'startTime': '2020-11-07T18:00:00-06:00',
#     'endTime': '2020-11-08T06:00:00-06:00',
#     'isDaytime': False,
#     'temperature': 56,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '20 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/night/few?size=medium',
#     'shortForecast': 'Mostly Clear',
#     'detailedForecast': 'Mostly clear, with a low around 56. South wind around 20 mph, with gusts as high as 30 mph.'},
#    {'number': 5,
#     'name': 'Sunday',
#     'startTime': '2020-11-08T06:00:00-06:00',
#     'endTime': '2020-11-08T18:00:00-06:00',
#     'isDaytime': True,
#     'temperature': 72,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '20 to 30 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/day/wind_sct?size=medium',
#     'shortForecast': 'Mostly Sunny',
#     'detailedForecast': 'Mostly sunny, with a high near 72. South wind 20 to 30 mph, with gusts as high as 40 mph.'},
#    {'number': 6,
#     'name': 'Sunday Night',
#     'startTime': '2020-11-08T18:00:00-06:00',
#     'endTime': '2020-11-09T06:00:00-06:00',
#     'isDaytime': False,
#     'temperature': 59,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '15 to 25 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/night/wind_sct/rain,20?size=medium',
#     'shortForecast': 'Partly Cloudy then Slight Chance Light Rain',
#     'detailedForecast': 'A slight chance of rain after midnight. Partly cloudy, with a low around 59. South wind 15 to 25 mph, with gusts as high as 30 mph. Chance of precipitation is 20%.'},
#    {'number': 7,
#     'name': 'Monday',
#     'startTime': '2020-11-09T06:00:00-06:00',
#     'endTime': '2020-11-09T18:00:00-06:00',
#     'isDaytime': True,
#     'temperature': 69,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '10 to 20 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/day/rain,40/tsra_sct,50?size=medium',
#     'shortForecast': 'Chance Light Rain',
#     'detailedForecast': 'A chance of rain before noon, then a chance of rain and a slight chance of thunderstorms. Partly sunny, with a high near 69. South wind 10 to 20 mph, with gusts as high as 35 mph. Chance of precipitation is 50%.'},
#    {'number': 8,
#     'name': 'Monday Night',
#     'startTime': '2020-11-09T18:00:00-06:00',
#     'endTime': '2020-11-10T06:00:00-06:00',
#     'isDaytime': False,
#     'temperature': 34,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '10 to 15 mph',
#     'windDirection': 'NW',
#     'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,60?size=medium',
#     'shortForecast': 'Light Rain Likely',
#     'detailedForecast': 'Rain likely and a chance of thunderstorms. Mostly cloudy, with a low around 34. Northwest wind 10 to 15 mph, with gusts as high as 30 mph. Chance of precipitation is 60%.'},
#    {'number': 9,
#     'name': 'Tuesday',
#     'startTime': '2020-11-10T06:00:00-06:00',
#     'endTime': '2020-11-10T18:00:00-06:00',
#     'isDaytime': True,
#     'temperature': 43,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '10 to 15 mph',
#     'windDirection': 'NW',
#     'icon': 'https://api.weather.gov/icons/land/day/snow,60/snow,40?size=medium',
#     'shortForecast': 'Slight Chance T-storms',
#     'detailedForecast': 'A slight chance of thunderstorms and rain and snow likely. Partly sunny, with a high near 43. Northwest wind 10 to 15 mph, with gusts as high as 25 mph. Chance of precipitation is 60%.'},
#    {'number': 10,
#     'name': 'Tuesday Night',
#     'startTime': '2020-11-10T18:00:00-06:00',
#     'endTime': '2020-11-11T06:00:00-06:00',
#     'isDaytime': False,
#     'temperature': 28,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '5 to 10 mph',
#     'windDirection': 'W',
#     'icon': 'https://api.weather.gov/icons/land/night/few?size=medium',
#     'shortForecast': 'Mostly Clear',
#     'detailedForecast': 'Mostly clear, with a low around 28.'},
#    {'number': 11,
#     'name': 'Veterans Day',
#     'startTime': '2020-11-11T06:00:00-06:00',
#     'endTime': '2020-11-11T18:00:00-06:00',
#     'isDaytime': True,
#     'temperature': 52,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '5 to 10 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/day/few?size=medium',
#     'shortForecast': 'Sunny',
#     'detailedForecast': 'Sunny, with a high near 52.'},
#    {'number': 12,
#     'name': 'Wednesday Night',
#     'startTime': '2020-11-11T18:00:00-06:00',
#     'endTime': '2020-11-12T06:00:00-06:00',
#     'isDaytime': False,
#     'temperature': 32,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '5 mph',
#     'windDirection': 'SE',
#     'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#     'shortForecast': 'Partly Cloudy',
#     'detailedForecast': 'Partly cloudy, with a low around 32.'},
#    {'number': 13,
#     'name': 'Thursday',
#     'startTime': '2020-11-12T06:00:00-06:00',
#     'endTime': '2020-11-12T18:00:00-06:00',
#     'isDaytime': True,
#     'temperature': 48,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '5 to 10 mph',
#     'windDirection': 'NE',
#     'icon': 'https://api.weather.gov/icons/land/day/bkn/rain,20?size=medium',
#     'shortForecast': 'Partly Sunny then Slight Chance Light Rain',
#     'detailedForecast': 'A slight chance of rain after noon. Partly sunny, with a high near 48. Chance of precipitation is 20%.'},
#    {'number': 14,
#     'name': 'Thursday Night',
#     'startTime': '2020-11-12T18:00:00-06:00',
#     'endTime': '2020-11-13T06:00:00-06:00',
#     'isDaytime': False,
#     'temperature': 30,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'windSpeed': '5 to 10 mph',
#     'windDirection': 'N',
#     'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#     'shortForecast': 'Partly Cloudy',
#     'detailedForecast': 'Partly cloudy, with a low around 30.'}]}}

# %%
# find the hourly forecast data
hourly_forecast_data = hourly_forecast['properties']['periods']
hourly_forecast_data
# Out:
# [{'number': 1,
#   'name': 'This Afternoon',
#   'startTime': '2020-11-06T15:00:00-06:00',
#   'endTime': '2020-11-06T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 78,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#   'shortForecast': 'Sunny',
#   'detailedForecast': 'Sunny, with a high near 78. South wind around 15 mph, with gusts as high as 25 mph.'},
#  {'number': 2,
#   'name': 'Tonight',
#   'startTime': '2020-11-06T18:00:00-06:00',
#   'endTime': '2020-11-07T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': 'Partly cloudy, with a low around 56. South wind around 15 mph, with gusts as high as 25 mph.'},
#  {'number': 3,
#   'name': 'Saturday',
#   'startTime': '2020-11-07T06:00:00-06:00',
#   'endTime': '2020-11-07T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 73,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 to 20 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': 'Mostly sunny, with a high near 73. South wind 15 to 20 mph, with gusts as high as 30 mph.'},
#  {'number': 4,
#   'name': 'Saturday Night',
#   'startTime': '2020-11-07T18:00:00-06:00',
#   'endTime': '2020-11-08T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '20 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=medium',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': 'Mostly clear, with a low around 56. South wind around 20 mph, with gusts as high as 30 mph.'},
#  {'number': 5,
#   'name': 'Sunday',
#   'startTime': '2020-11-08T06:00:00-06:00',
#   'endTime': '2020-11-08T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 72,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '20 to 30 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/wind_sct?size=medium',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': 'Mostly sunny, with a high near 72. South wind 20 to 30 mph, with gusts as high as 40 mph.'},
#  {'number': 6,
#   'name': 'Sunday Night',
#   'startTime': '2020-11-08T18:00:00-06:00',
#   'endTime': '2020-11-09T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 to 25 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/night/wind_sct/rain,20?size=medium',
#   'shortForecast': 'Partly Cloudy then Slight Chance Light Rain',
#   'detailedForecast': 'A slight chance of rain after midnight. Partly cloudy, with a low around 59. South wind 15 to 25 mph, with gusts as high as 30 mph. Chance of precipitation is 20%.'},
#  {'number': 7,
#   'name': 'Monday',
#   'startTime': '2020-11-09T06:00:00-06:00',
#   'endTime': '2020-11-09T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 69,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 to 20 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/rain,40/tsra_sct,50?size=medium',
#   'shortForecast': 'Chance Light Rain',
#   'detailedForecast': 'A chance of rain before noon, then a chance of rain and a slight chance of thunderstorms. Partly sunny, with a high near 69. South wind 10 to 20 mph, with gusts as high as 35 mph. Chance of precipitation is 50%.'},
#  {'number': 8,
#   'name': 'Monday Night',
#   'startTime': '2020-11-09T18:00:00-06:00',
#   'endTime': '2020-11-10T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 34,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 to 15 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,60?size=medium',
#   'shortForecast': 'Light Rain Likely',
#   'detailedForecast': 'Rain likely and a chance of thunderstorms. Mostly cloudy, with a low around 34. Northwest wind 10 to 15 mph, with gusts as high as 30 mph. Chance of precipitation is 60%.'},
#  {'number': 9,
#   'name': 'Tuesday',
#   'startTime': '2020-11-10T06:00:00-06:00',
#   'endTime': '2020-11-10T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 43,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 to 15 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/snow,60/snow,40?size=medium',
#   'shortForecast': 'Slight Chance T-storms',
#   'detailedForecast': 'A slight chance of thunderstorms and rain and snow likely. Partly sunny, with a high near 43. Northwest wind 10 to 15 mph, with gusts as high as 25 mph. Chance of precipitation is 60%.'},
#  {'number': 10,
#   'name': 'Tuesday Night',
#   'startTime': '2020-11-10T18:00:00-06:00',
#   'endTime': '2020-11-11T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 28,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 to 10 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=medium',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': 'Mostly clear, with a low around 28.'},
#  {'number': 11,
#   'name': 'Veterans Day',
#   'startTime': '2020-11-11T06:00:00-06:00',
#   'endTime': '2020-11-11T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 52,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 to 10 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=medium',
#   'shortForecast': 'Sunny',
#   'detailedForecast': 'Sunny, with a high near 52.'},
#  {'number': 12,
#   'name': 'Wednesday Night',
#   'startTime': '2020-11-11T18:00:00-06:00',
#   'endTime': '2020-11-12T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 32,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': 'Partly cloudy, with a low around 32.'},
#  {'number': 13,
#   'name': 'Thursday',
#   'startTime': '2020-11-12T06:00:00-06:00',
#   'endTime': '2020-11-12T18:00:00-06:00',
#   'isDaytime': True,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 to 10 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn/rain,20?size=medium',
#   'shortForecast': 'Partly Sunny then Slight Chance Light Rain',
#   'detailedForecast': 'A slight chance of rain after noon. Partly sunny, with a high near 48. Chance of precipitation is 20%.'},
#  {'number': 14,
#   'name': 'Thursday Night',
#   'startTime': '2020-11-12T18:00:00-06:00',
#   'endTime': '2020-11-13T06:00:00-06:00',
#   'isDaytime': False,
#   'temperature': 30,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 to 10 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': 'Partly cloudy, with a low around 30.'}]

# %%
# examine the data
hourly_forecast_data[0]
# Out:
# {'number': 1,
#  'name': 'This Afternoon',
#  'startTime': '2020-11-06T15:00:00-06:00',
#  'endTime': '2020-11-06T18:00:00-06:00',
#  'isDaytime': True,
#  'temperature': 78,
#  'temperatureUnit': 'F',
#  'temperatureTrend': None,
#  'windSpeed': '15 mph',
#  'windDirection': 'S',
#  'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#  'shortForecast': 'Sunny',
#  'detailedForecast': 'Sunny, with a high near 78. South wind around 15 mph, with gusts as high as 25 mph.'}

# %% [markdown]
# ### Convert and Save Data in Pandas Dataframe

# %%
# save the data in a datafarame
import pandas as pd

hourly_forecast_df = pd.json_normalize(hourly_forecast_data)
hourly_forecast_df
# Out:
#     number             name                  startTime  \
# 0        1   This Afternoon  2020-11-06T15:00:00-06:00
# 1        2          Tonight  2020-11-06T18:00:00-06:00
# 2        3         Saturday  2020-11-07T06:00:00-06:00
# 3        4   Saturday Night  2020-11-07T18:00:00-06:00
# 4        5           Sunday  2020-11-08T06:00:00-06:00
# 5        6     Sunday Night  2020-11-08T18:00:00-06:00
# 6        7           Monday  2020-11-09T06:00:00-06:00
# 7        8     Monday Night  2020-11-09T18:00:00-06:00
# 8        9          Tuesday  2020-11-10T06:00:00-06:00
# 9       10    Tuesday Night  2020-11-10T18:00:00-06:00
# 10      11     Veterans Day  2020-11-11T06:00:00-06:00
# 11      12  Wednesday Night  2020-11-11T18:00:00-06:00
# 12      13         Thursday  2020-11-12T06:00:00-06:00
# 13      14   Thursday Night  2020-11-12T18:00:00-06:00
#
#                       endTime  isDaytime  temperature temperatureUnit  \
# 0   2020-11-06T18:00:00-06:00       True           78               F
# 1   2020-11-07T06:00:00-06:00      False           56               F
# 2   2020-11-07T18:00:00-06:00       True           73               F
# 3   2020-11-08T06:00:00-06:00      False           56               F
# 4   2020-11-08T18:00:00-06:00       True           72               F
# 5   2020-11-09T06:00:00-06:00      False           59               F
# 6   2020-11-09T18:00:00-06:00       True           69               F
# 7   2020-11-10T06:00:00-06:00      False           34               F
# 8   2020-11-10T18:00:00-06:00       True           43               F
# 9   2020-11-11T06:00:00-06:00      False           28               F
# 10  2020-11-11T18:00:00-06:00       True           52               F
# 11  2020-11-12T06:00:00-06:00      False           32               F
# 12  2020-11-12T18:00:00-06:00       True           48               F
# 13  2020-11-13T06:00:00-06:00      False           30               F
#
#    temperatureTrend     windSpeed windDirection  \
# 0              None        15 mph             S
# 1              None        15 mph             S
# 2              None  15 to 20 mph             S
# 3              None        20 mph             S
# 4              None  20 to 30 mph             S
# 5              None  15 to 25 mph             S
# 6              None  10 to 20 mph             S
# 7              None  10 to 15 mph            NW
# 8              None  10 to 15 mph            NW
# 9              None   5 to 10 mph             W
# 10             None   5 to 10 mph             S
# 11             None         5 mph            SE
# 12             None   5 to 10 mph            NE
# 13             None   5 to 10 mph             N
#
#                                                  icon  \
# 0   https://api.weather.gov/icons/land/day/skc?siz...
# 1   https://api.weather.gov/icons/land/night/sct?s...
# 2   https://api.weather.gov/icons/land/day/sct?siz...
# 3   https://api.weather.gov/icons/land/night/few?s...
# 4   https://api.weather.gov/icons/land/day/wind_sc...
# 5   https://api.weather.gov/icons/land/night/wind_...
# 6   https://api.weather.gov/icons/land/day/rain,40...
# 7   https://api.weather.gov/icons/land/night/tsra_...
# 8   https://api.weather.gov/icons/land/day/snow,60...
# 9   https://api.weather.gov/icons/land/night/few?s...
# 10  https://api.weather.gov/icons/land/day/few?siz...
# 11  https://api.weather.gov/icons/land/night/sct?s...
# 12  https://api.weather.gov/icons/land/day/bkn/rai...
# 13  https://api.weather.gov/icons/land/night/sct?s...
#
#                                   shortForecast  \
# 0                                         Sunny
# 1                                 Partly Cloudy
# 2                                  Mostly Sunny
# 3                                  Mostly Clear
# 4                                  Mostly Sunny
# 5   Partly Cloudy then Slight Chance Light Rain
# 6                             Chance Light Rain
# 7                             Light Rain Likely
# 8                        Slight Chance T-storms
# 9                                  Mostly Clear
# 10                                        Sunny
# 11                                Partly Cloudy
# 12   Partly Sunny then Slight Chance Light Rain
# 13                                Partly Cloudy
#
#                                      detailedForecast
# 0   Sunny, with a high near 78. South wind around ...
# 1   Partly cloudy, with a low around 56. South win...
# 2   Mostly sunny, with a high near 73. South wind ...
# 3   Mostly clear, with a low around 56. South wind...
# 4   Mostly sunny, with a high near 72. South wind ...
# 5   A slight chance of rain after midnight. Partly...
# 6   A chance of rain before noon, then a chance of...
# 7   Rain likely and a chance of thunderstorms. Mos...
# 8   A slight chance of thunderstorms and rain and ...
# 9                 Mostly clear, with a low around 28.
# 10                        Sunny, with a high near 52.
# 11               Partly cloudy, with a low around 32.
# 12  A slight chance of rain after noon. Partly sun...
# 13               Partly cloudy, with a low around 30.

# %% [markdown]
# - Now, I get a dataframe that I can further process for more analysis.

# %%
# convert the time into pandas datetime
hourly_forecast_df['startDate'] = pd.to_datetime(hourly_forecast_df['startTime']).dt.date
hourly_forecast_df['dayStartTime'] = pd.to_datetime(hourly_forecast_df['startTime']).dt.time
hourly_forecast_df['endDate'] = pd.to_datetime(hourly_forecast_df['endTime']).dt.date
hourly_forecast_df['dayEndTime'] = pd.to_datetime(hourly_forecast_df['endTime']).dt.time
hourly_forecast_df
# Out:
#     number             name                  startTime  \
# 0        1   This Afternoon  2020-11-06T15:00:00-06:00
# 1        2          Tonight  2020-11-06T18:00:00-06:00
# 2        3         Saturday  2020-11-07T06:00:00-06:00
# 3        4   Saturday Night  2020-11-07T18:00:00-06:00
# 4        5           Sunday  2020-11-08T06:00:00-06:00
# 5        6     Sunday Night  2020-11-08T18:00:00-06:00
# 6        7           Monday  2020-11-09T06:00:00-06:00
# 7        8     Monday Night  2020-11-09T18:00:00-06:00
# 8        9          Tuesday  2020-11-10T06:00:00-06:00
# 9       10    Tuesday Night  2020-11-10T18:00:00-06:00
# 10      11     Veterans Day  2020-11-11T06:00:00-06:00
# 11      12  Wednesday Night  2020-11-11T18:00:00-06:00
# 12      13         Thursday  2020-11-12T06:00:00-06:00
# 13      14   Thursday Night  2020-11-12T18:00:00-06:00
#
#                       endTime  isDaytime  temperature temperatureUnit  \
# 0   2020-11-06T18:00:00-06:00       True           78               F
# 1   2020-11-07T06:00:00-06:00      False           56               F
# 2   2020-11-07T18:00:00-06:00       True           73               F
# 3   2020-11-08T06:00:00-06:00      False           56               F
# 4   2020-11-08T18:00:00-06:00       True           72               F
# 5   2020-11-09T06:00:00-06:00      False           59               F
# 6   2020-11-09T18:00:00-06:00       True           69               F
# 7   2020-11-10T06:00:00-06:00      False           34               F
# 8   2020-11-10T18:00:00-06:00       True           43               F
# 9   2020-11-11T06:00:00-06:00      False           28               F
# 10  2020-11-11T18:00:00-06:00       True           52               F
# 11  2020-11-12T06:00:00-06:00      False           32               F
# 12  2020-11-12T18:00:00-06:00       True           48               F
# 13  2020-11-13T06:00:00-06:00      False           30               F
#
#    temperatureTrend     windSpeed windDirection  \
# 0              None        15 mph             S
# 1              None        15 mph             S
# 2              None  15 to 20 mph             S
# 3              None        20 mph             S
# 4              None  20 to 30 mph             S
# 5              None  15 to 25 mph             S
# 6              None  10 to 20 mph             S
# 7              None  10 to 15 mph            NW
# 8              None  10 to 15 mph            NW
# 9              None   5 to 10 mph             W
# 10             None   5 to 10 mph             S
# 11             None         5 mph            SE
# 12             None   5 to 10 mph            NE
# 13             None   5 to 10 mph             N
#
#                                                  icon  \
# 0   https://api.weather.gov/icons/land/day/skc?siz...
# 1   https://api.weather.gov/icons/land/night/sct?s...
# 2   https://api.weather.gov/icons/land/day/sct?siz...
# 3   https://api.weather.gov/icons/land/night/few?s...
# 4   https://api.weather.gov/icons/land/day/wind_sc...
# 5   https://api.weather.gov/icons/land/night/wind_...
# 6   https://api.weather.gov/icons/land/day/rain,40...
# 7   https://api.weather.gov/icons/land/night/tsra_...
# 8   https://api.weather.gov/icons/land/day/snow,60...
# 9   https://api.weather.gov/icons/land/night/few?s...
# 10  https://api.weather.gov/icons/land/day/few?siz...
# 11  https://api.weather.gov/icons/land/night/sct?s...
# 12  https://api.weather.gov/icons/land/day/bkn/rai...
# 13  https://api.weather.gov/icons/land/night/sct?s...
#
#                                   shortForecast  \
# 0                                         Sunny
# 1                                 Partly Cloudy
# 2                                  Mostly Sunny
# 3                                  Mostly Clear
# 4                                  Mostly Sunny
# 5   Partly Cloudy then Slight Chance Light Rain
# 6                             Chance Light Rain
# 7                             Light Rain Likely
# 8                        Slight Chance T-storms
# 9                                  Mostly Clear
# 10                                        Sunny
# 11                                Partly Cloudy
# 12   Partly Sunny then Slight Chance Light Rain
# 13                                Partly Cloudy
#
#                                      detailedForecast   startDate  \
# 0   Sunny, with a high near 78. South wind around ...  2020-11-06
# 1   Partly cloudy, with a low around 56. South win...  2020-11-06
# 2   Mostly sunny, with a high near 73. South wind ...  2020-11-07
# 3   Mostly clear, with a low around 56. South wind...  2020-11-07
# 4   Mostly sunny, with a high near 72. South wind ...  2020-11-08
# 5   A slight chance of rain after midnight. Partly...  2020-11-08
# 6   A chance of rain before noon, then a chance of...  2020-11-09
# 7   Rain likely and a chance of thunderstorms. Mos...  2020-11-09
# 8   A slight chance of thunderstorms and rain and ...  2020-11-10
# 9                 Mostly clear, with a low around 28.  2020-11-10
# 10                        Sunny, with a high near 52.  2020-11-11
# 11               Partly cloudy, with a low around 32.  2020-11-11
# 12  A slight chance of rain after noon. Partly sun...  2020-11-12
# 13               Partly cloudy, with a low around 30.  2020-11-12
#
#    dayStartTime     endDate dayEndTime
# 0      15:00:00  2020-11-06   18:00:00
# 1      18:00:00  2020-11-07   06:00:00
# 2      06:00:00  2020-11-07   18:00:00
# 3      18:00:00  2020-11-08   06:00:00
# 4      06:00:00  2020-11-08   18:00:00
# 5      18:00:00  2020-11-09   06:00:00
# 6      06:00:00  2020-11-09   18:00:00
# 7      18:00:00  2020-11-10   06:00:00
# 8      06:00:00  2020-11-10   18:00:00
# 9      18:00:00  2020-11-11   06:00:00
# 10     06:00:00  2020-11-11   18:00:00
# 11     18:00:00  2020-11-12   06:00:00
# 12     06:00:00  2020-11-12   18:00:00
# 13     18:00:00  2020-11-13   06:00:00

# %%
# drop some cols and re-arrange them
hourly_forecast_df.columns.values
# Out:
# array(['number', 'name', 'startTime', 'endTime', 'isDaytime',
#        'temperature', 'temperatureUnit', 'temperatureTrend', 'windSpeed',
#        'windDirection', 'icon', 'shortForecast', 'detailedForecast',
#        'startDate', 'dayStartTime', 'endDate', 'dayEndTime'], dtype=object)

# %%
cols = ['number', 'name', 'startDate', 'dayStartTime', 'endDate', 'dayEndTime', 'isDaytime',
       'temperature', 'temperatureUnit', 'temperatureTrend', 'windSpeed',
       'windDirection', 'shortForecast', 'detailedForecast', 'icon']
hourly_forecast_cean_df = pd.DataFrame(hourly_forecast_df, columns=cols)
hourly_forecast_cean_df
# Out:
#     number             name   startDate dayStartTime     endDate dayEndTime  \
# 0        1   This Afternoon  2020-11-06     15:00:00  2020-11-06   18:00:00
# 1        2          Tonight  2020-11-06     18:00:00  2020-11-07   06:00:00
# 2        3         Saturday  2020-11-07     06:00:00  2020-11-07   18:00:00
# 3        4   Saturday Night  2020-11-07     18:00:00  2020-11-08   06:00:00
# 4        5           Sunday  2020-11-08     06:00:00  2020-11-08   18:00:00
# 5        6     Sunday Night  2020-11-08     18:00:00  2020-11-09   06:00:00
# 6        7           Monday  2020-11-09     06:00:00  2020-11-09   18:00:00
# 7        8     Monday Night  2020-11-09     18:00:00  2020-11-10   06:00:00
# 8        9          Tuesday  2020-11-10     06:00:00  2020-11-10   18:00:00
# 9       10    Tuesday Night  2020-11-10     18:00:00  2020-11-11   06:00:00
# 10      11     Veterans Day  2020-11-11     06:00:00  2020-11-11   18:00:00
# 11      12  Wednesday Night  2020-11-11     18:00:00  2020-11-12   06:00:00
# 12      13         Thursday  2020-11-12     06:00:00  2020-11-12   18:00:00
# 13      14   Thursday Night  2020-11-12     18:00:00  2020-11-13   06:00:00
#
#     isDaytime  temperature temperatureUnit temperatureTrend     windSpeed  \
# 0        True           78               F             None        15 mph
# 1       False           56               F             None        15 mph
# 2        True           73               F             None  15 to 20 mph
# 3       False           56               F             None        20 mph
# 4        True           72               F             None  20 to 30 mph
# 5       False           59               F             None  15 to 25 mph
# 6        True           69               F             None  10 to 20 mph
# 7       False           34               F             None  10 to 15 mph
# 8        True           43               F             None  10 to 15 mph
# 9       False           28               F             None   5 to 10 mph
# 10       True           52               F             None   5 to 10 mph
# 11      False           32               F             None         5 mph
# 12       True           48               F             None   5 to 10 mph
# 13      False           30               F             None   5 to 10 mph
#
#    windDirection                                shortForecast  \
# 0              S                                        Sunny
# 1              S                                Partly Cloudy
# 2              S                                 Mostly Sunny
# 3              S                                 Mostly Clear
# 4              S                                 Mostly Sunny
# 5              S  Partly Cloudy then Slight Chance Light Rain
# 6              S                            Chance Light Rain
# 7             NW                            Light Rain Likely
# 8             NW                       Slight Chance T-storms
# 9              W                                 Mostly Clear
# 10             S                                        Sunny
# 11            SE                                Partly Cloudy
# 12            NE   Partly Sunny then Slight Chance Light Rain
# 13             N                                Partly Cloudy
#
#                                      detailedForecast  \
# 0   Sunny, with a high near 78. South wind around ...
# 1   Partly cloudy, with a low around 56. South win...
# 2   Mostly sunny, with a high near 73. South wind ...
# 3   Mostly clear, with a low around 56. South wind...
# 4   Mostly sunny, with a high near 72. South wind ...
# 5   A slight chance of rain after midnight. Partly...
# 6   A chance of rain before noon, then a chance of...
# 7   Rain likely and a chance of thunderstorms. Mos...
# 8   A slight chance of thunderstorms and rain and ...
# 9                 Mostly clear, with a low around 28.
# 10                        Sunny, with a high near 52.
# 11               Partly cloudy, with a low around 32.
# 12  A slight chance of rain after noon. Partly sun...
# 13               Partly cloudy, with a low around 30.
#
#                                                  icon
# 0   https://api.weather.gov/icons/land/day/skc?siz...
# 1   https://api.weather.gov/icons/land/night/sct?s...
# 2   https://api.weather.gov/icons/land/day/sct?siz...
# 3   https://api.weather.gov/icons/land/night/few?s...
# 4   https://api.weather.gov/icons/land/day/wind_sc...
# 5   https://api.weather.gov/icons/land/night/wind_...
# 6   https://api.weather.gov/icons/land/day/rain,40...
# 7   https://api.weather.gov/icons/land/night/tsra_...
# 8   https://api.weather.gov/icons/land/day/snow,60...
# 9   https://api.weather.gov/icons/land/night/few?s...
# 10  https://api.weather.gov/icons/land/day/few?siz...
# 11  https://api.weather.gov/icons/land/night/sct?s...
# 12  https://api.weather.gov/icons/land/day/bkn/rai...
# 13  https://api.weather.gov/icons/land/night/sct?s...

# %%
hourly_forecast_cean_df.to_csv('hourly_weather_forecast.csv')

# %% [markdown]
# ## Summary
#
# - Above is an example of extracting data from APIs and save the data as a Pandas dataframe for further processing.
